# %%
import numpy as np
import pandas as pd

# %%
file_path = "C:/Users/82108/Desktop/jw/프로젝트/반려동물등록현황전처리전/서울_반려동물_등록현황/서울특별시_동대문구_반려동물등록현황_20201014.csv"
df_raw = pd.read_csv(file_path, encoding='euc-kr')
# 파일불러오기 
# 인코딩 문제 발생, 현재 파일이 EUC-KR로 인코딩되어 있으므로 encoding='euc-kr'으로 지정

# %%
# 원본 데이터
df_raw.head()
# Out:
#   읍면동(법정동)  등록주체_시군구  등록주체_대행업체  등록주체_기타(이벤트 등)  등록형태_내장형RFID  등록형태_외장형RFID  \
# 0      신설동       6.0      188.0             0.0          70.0         103.0
# 1      용두동      70.0     1275.0             2.0         508.0         721.0
# 2      이문동      52.0     2320.0             1.0        1034.0        1196.0
# 3      장안동     133.0     3450.0             1.0        1508.0        1871.0
# 4      전농동      76.0     1882.0             2.0        1030.0         800.0
#
#    등록형태_인식표RFID  등록품종수  동물소유자수  동물소유자당동물등록수    총등록수     데이터기준일자
# 0          21.0   32.0   147.0         1.32   194.0  2020-10-14
# 1         118.0   64.0  1025.0         1.31  1347.0  2020-10-14
# 2         143.0   67.0  1344.0         1.77  2373.0  2020-10-14
# 3         205.0   78.0  2745.0         1.31  3584.0  2020-10-14
# 4         130.0   67.0  1559.0         1.26  1960.0  2020-10-14

# %%
# 원본데이터 복사
dongdaemun = df_raw.copy()

# %%
dongdaemun['구']="동대문구"
dongdaemun.head()
# Out:
#   읍면동(법정동)  등록주체_시군구  등록주체_대행업체  등록주체_기타(이벤트 등)  등록형태_내장형RFID  등록형태_외장형RFID  \
# 0      신설동       6.0      188.0             0.0          70.0         103.0
# 1      용두동      70.0     1275.0             2.0         508.0         721.0
# 2      이문동      52.0     2320.0             1.0        1034.0        1196.0
# 3      장안동     133.0     3450.0             1.0        1508.0        1871.0
# 4      전농동      76.0     1882.0             2.0        1030.0         800.0
#
#    등록형태_인식표RFID  등록품종수  동물소유자수  동물소유자당동물등록수    총등록수     데이터기준일자     구
# 0          21.0   32.0   147.0         1.32   194.0  2020-10-14  동대문구
# 1         118.0   64.0  1025.0         1.31  1347.0  2020-10-14  동대문구
# 2         143.0   67.0  1344.0         1.77  2373.0  2020-10-14  동대문구
# 3         205.0   78.0  2745.0         1.31  3584.0  2020-10-14  동대문구
# 4         130.0   67.0  1559.0         1.26  1960.0  2020-10-14  동대문구

# %%
# 필요한 컬럼만 남기기
dongdaemun = dongdaemun[['구','읍면동(법정동)','동물소유자수','총등록수']]

# 컬럼명 변경하기
dongdaemun.rename(columns={'구':'Gu',
                            '읍면동(법정동)':'Dong',
                            '동물소유자수':'Pet_Owners',
                            '총등록수':'Total_Registrations'},
                  inplace=True)

dongdaemun
# Out:
# C:\Users\82108\AppData\Local\Temp\ipykernel_26784\551363796.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dongdaemun.rename(columns={'구':'Gu',
#       Gu  Dong  Pet_Owners  Total_Registrations
# 0   동대문구   신설동       147.0                194.0
# 1   동대문구   용두동      1025.0               1347.0
# 2   동대문구   이문동      1344.0               2373.0
# 3   동대문구   장안동      2745.0               3584.0
# 4   동대문구   전농동      1559.0               1960.0
# 5   동대문구   제기동       901.0               1194.0
# 6   동대문구   회기동       285.0                335.0
# 7   동대문구   휘경동      1130.0               1413.0
# 8   동대문구  답십리동      1873.0               2538.0
# 9   동대문구  청량리동       659.0                873.0
# 10  동대문구   NaN         NaN                  NaN

# %%
# 결측치 제거
dongdaemun.dropna(inplace=True)
dongdaemun
# Out:
# C:\Users\82108\AppData\Local\Temp\ipykernel_26784\2760320794.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dongdaemun.dropna(inplace=True)
#      Gu  Dong  Pet_Owners  Total_Registrations
# 0  동대문구   신설동       147.0                194.0
# 1  동대문구   용두동      1025.0               1347.0
# 2  동대문구   이문동      1344.0               2373.0
# 3  동대문구   장안동      2745.0               3584.0
# 4  동대문구   전농동      1559.0               1960.0
# 5  동대문구   제기동       901.0               1194.0
# 6  동대문구   회기동       285.0                335.0
# 7  동대문구   휘경동      1130.0               1413.0
# 8  동대문구  답십리동      1873.0               2538.0
# 9  동대문구  청량리동       659.0                873.0

# %%
# 파일 저장하기
dongdaemun.to_csv("./dongdaemun_지우_v1.csv")
